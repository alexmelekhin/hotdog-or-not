# %% [markdown]
# # Классификатор "Хотдог или нет"

# %% [markdown]
# ## Импорт библиотек

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# **Используемые версии Python и библиотек:**

# %%
print(f"Python {sys.version}\n")
print(f"matplotlib {matplotlib.__version__}")
print(f"numpy {np.__version__}")
print(f"PIL {PIL.__version__}")
print(f"tensorflow {tf.__version__}")
# Out:
# Python 3.7.9 (default, Aug 31 2020, 07:22:35)
# [Clang 10.0.0 ]
#
# matplotlib 3.3.2
# numpy 1.19.2
# PIL 8.0.1
# tensorflow 2.4.0

# %% [markdown]
# ## Определение random_seed
#
# Во многих функциях (например, при делении датасета на train и valid) нужно указывать seed для воспроизводимости эксперимента.

# %%
random_seed = 42

# %% [markdown]
# ## Создание датасета
#
# Необходимо скачать датасет (всю папку) по ссылке и сохранить папку dataset в одной директории с этим jupyter-ноутбуком:
# https://drive.google.com/drive/folders/1RTz-jvqyP-4uxTkOSNaE7dEx1gdc_mEP?usp=sharing
#
# Папка dataset имеет следующую структуру:
# ```
# dataset/
#     train/
#         hotdog/
#         nothotdog/
#     test/
#         hotdog/
#         nothotdog/
# ```
# Содержимое папки train будет использоваться при обучении модели с выделением валидационной выборки. Содержимое папки test будет использоваться для итогового тестирования модели (эти данные модель не увидит при обучении).

# %%
import pathlib

data_train_dir = pathlib.Path("dataset/train/")
data_test_dir = pathlib.Path("dataset/test/")

# %%
image_train_count = len(list(data_train_dir.glob('*/*.jpg')))
print(f"Train size: {image_train_count}")

image_test_count = len(list(data_test_dir.glob('*/*.jpg')))
print(f"Test size: {image_test_count}")
# Out:
# Train size: 1604
# Test size: 228

# %% [markdown]
# Пример хотдога:

# %%
hotdogs = list(data_train_dir.glob('hotdog/*'))
PIL.Image.open(str(hotdogs[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7F7FE5768C10>

# %% [markdown]
# В качестве изображений "не хотдогов" я собрал фотографии людей, питомцев, мебели и другой еды, так как предположительно именно такие фото пользователи будут загружать для проверки классификатора. Вот один из примеров:

# %%
nothotdogs = list(data_train_dir.glob('nothotdog/*'))
PIL.Image.open(str(nothotdogs[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7F7FDDF42150>

# %% [markdown]
# Разделим содержимое train на обучающую и валидационную выборки и создадим тестовый датасет:

# %%
batch_size = 32

print("Creating train dataset:")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_train_dir,
    validation_split=0.2,
    subset="training",
    seed=random_seed,
    batch_size=batch_size)

print("Creating validation dataset:")
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_train_dir,
    validation_split=0.2,
    subset="validation",
    seed=random_seed,
    batch_size=batch_size)

print("Creating testing dataset:")
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_test_dir,
    seed=random_seed,
    batch_size=batch_size)
# Out:
# Creating train dataset:
# Found 1604 files belonging to 2 classes.
# Using 1284 files for training.
# Creating validation dataset:
# Found 1604 files belonging to 2 classes.
# Using 320 files for validation.
# Creating testing dataset:
# Found 228 files belonging to 2 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['hotdog', 'nothotdog']

# %% [markdown]
# Примеры изображений из созданного датасета:

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Dataset.cache() и Dataset.prefetch()

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Создание baseline модели

# %%
num_classes = 2
img_height = 200
img_width = 200

baseline_model = Sequential([
    layers.experimental.preprocessing.Resizing(img_height, img_width, interpolation='bilinear', name=None),
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3), name=None),
    layers.Conv2D(16, 3, padding='same', activation='relu', name=None),
    layers.MaxPooling2D(name=None),
    layers.Conv2D(32, 3, padding='same', activation='relu', name=None),
    layers.MaxPooling2D(name=None),
    layers.Conv2D(64, 3, padding='same', activation='relu', name=None),
    layers.MaxPooling2D(name=None),
    layers.Flatten(name=None),
    layers.Dense(128, activation='relu', name=None),
    layers.Dense(num_classes, name=None)
])

# %%
baseline_model.compile(optimizer='adam',
                       loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                       metrics=['accuracy'])

# %%
epochs=10
history = baseline_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/10
# 41/41 [==============================] - 37s 860ms/step - loss: 1.0631 - accuracy: 0.5003 - val_loss: 0.5788 - val_accuracy: 0.6875
# Epoch 2/10
# 41/41 [==============================] - 31s 763ms/step - loss: 0.5443 - accuracy: 0.7549 - val_loss: 0.4803 - val_accuracy: 0.7656
# Epoch 3/10
# 41/41 [==============================] - 32s 785ms/step - loss: 0.4282 - accuracy: 0.8173 - val_loss: 0.4707 - val_accuracy: 0.7750
# Epoch 4/10
# 41/41 [==============================] - 31s 756ms/step - loss: 0.3685 - accuracy: 0.8397 - val_loss: 0.4529 - val_accuracy: 0.7844
# Epoch 5/10
# 41/41 [==============================] - 30s 725ms/step - loss: 0.3325 - accuracy: 0.8668 - val_loss: 0.4311 - val_accuracy: 0.7969
# Epoch 6/10
# 41/41 [==============================] - 31s 736ms/step - loss: 0.2848 - accuracy: 0.8941 - val_loss: 0.4962 - val_accuracy: 0.7625
# Epoch 7/10
# 41/41 [==============================] - 32s 782ms/step - loss: 0.2661 - accuracy: 0.9097 - val_loss: 0.6442 - val_accuracy: 0.7188
# Epoch 8/10
# 41/41 [==============================] - 37s 901ms/step - loss: 0.2158 - accuracy: 0.9207 - val_loss: 0.9679 - val_accuracy: 0.7063
# Epoch 9/10
# 41/41 [==============================] - 27s 645ms/step - loss: 0.2430 - accuracy: 0.9075 - val_loss: 0.7070 - val_accuracy: 0.7469
# Epoch 10/10
# 41/41 [==============================] - 27s 658ms/step - loss: 0.3032 - accuracy: 0.8870 - val_loss: 0.7527 - val_accuracy: 0.7281

# %%
baseline_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resizing (Resizing)          (None, 200, 200, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 200, 200, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 200, 200, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 40000)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5120128
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 5,143,970
# Trainable params: 5,143,970
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Визуализация результатов обучения

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Основной pipeline

# %% [markdown]
# На графике Training and Validation Accuracy выше видно, что качество работы модели на обучающих данных растет, в то время как качество на валидации остается примерно на одинаковом уровне. Также можно заметить, что разница между точностью модели на обучающих данных и точностью на валидации довольно велика. Все это - признаки **переобучения**.
# Причина переобучения заключается в небольшом размере датасета - модели не хватает данных, чтобы выявить основные закономерности.

# %% [markdown]
# ### Увеличение данных (Data augmentation)
# Сгенерируем дополнительные данные в обучающем датасете путем случайных ротаций/зумирования/переворотов исходных изображений

# %%
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                     input_shape=(img_height, 
                                                                  img_width,
                                                                  3)),
        layers.experimental.preprocessing.RandomRotation(0.1),
        layers.experimental.preprocessing.RandomZoom(0.1),
    ]
)

# %% [markdown]
# Пример сгенерированных изображений:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ### Dropout
# Другой способ уменьшить переобучение - это ввести dropout в сеть. Это форма регуляризации, которая заставляет веса в сети принимать только малые значения, что делает распределение значений веса более регулярным, и сеть может уменьшить переобучение на небольших тренировочных примерах.
# Для этого добавим слой ```layers.Dropout(0.2)``` в нейросеть.
#
# ***В результате получаем следующую модель:***

# %%
model = Sequential([
    layers.experimental.preprocessing.Resizing(img_height, img_width, interpolation='bilinear', name=None),
    data_augmentation,
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3), name=None),
    layers.Conv2D(16, 3, padding='same', activation='relu', name=None),
    layers.MaxPooling2D(name=None),
    layers.Conv2D(32, 3, padding='same', activation='relu', name=None),
    layers.MaxPooling2D(name=None),
    layers.Conv2D(64, 3, padding='same', activation='relu', name=None),
    layers.MaxPooling2D(name=None),
    layers.Dropout(0.2),
    layers.Flatten(name=None),
    layers.Dense(128, activation='relu', name=None),
    layers.Dense(num_classes, name=None)
])

# %% [markdown]
# ### Компиляция и обучение модели

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=15
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/15
# 41/41 [==============================] - 33s 790ms/step - loss: 1.2634 - accuracy: 0.5837 - val_loss: 0.5837 - val_accuracy: 0.7437
# Epoch 2/15
# 41/41 [==============================] - 33s 804ms/step - loss: 0.4674 - accuracy: 0.7901 - val_loss: 0.4964 - val_accuracy: 0.7750
# Epoch 3/15
# 41/41 [==============================] - 34s 820ms/step - loss: 0.4081 - accuracy: 0.8195 - val_loss: 0.4648 - val_accuracy: 0.7688
# Epoch 4/15
# 41/41 [==============================] - 40s 989ms/step - loss: 0.3917 - accuracy: 0.8260 - val_loss: 0.4662 - val_accuracy: 0.7750
# Epoch 5/15
# 41/41 [==============================] - 33s 794ms/step - loss: 0.3765 - accuracy: 0.8414 - val_loss: 0.4627 - val_accuracy: 0.7656
# Epoch 6/15
# 41/41 [==============================] - 33s 801ms/step - loss: 0.3729 - accuracy: 0.8496 - val_loss: 0.4781 - val_accuracy: 0.7844
# Epoch 7/15
# 41/41 [==============================] - 32s 784ms/step - loss: 0.3472 - accuracy: 0.8574 - val_loss: 0.5112 - val_accuracy: 0.7844
# Epoch 8/15
# 41/41 [==============================] - 34s 818ms/step - loss: 0.3402 - accuracy: 0.8594 - val_loss: 0.4855 - val_accuracy: 0.7875
# Epoch 9/15
# 41/41 [==============================] - 36s 880ms/step - loss: 0.3389 - accuracy: 0.8644 - val_loss: 0.4858 - val_accuracy: 0.7812
# Epoch 10/15
# 41/41 [==============================] - 31s 762ms/step - loss: 0.3201 - accuracy: 0.8682 - val_loss: 0.4775 - val_accuracy: 0.7906
# Epoch 11/15
# 41/41 [==============================] - 32s 770ms/step - loss: 0.3397 - accuracy: 0.8586 - val_loss: 0.5073 - val_accuracy: 0.7812
# Epoch 12/15
# 41/41 [==============================] - 35s 862ms/step - loss: 0.3417 - accuracy: 0.8621 - val_loss: 0.4632 - val_accuracy: 0.7875
# Epoch 13/15
# 41/41 [==============================] - 34s 842ms/step - loss: 0.3493 - accuracy: 0.8531 - val_loss: 0.4697 - val_accuracy: 0.7906
# Epoch 14/15
# 41/41 [==============================] - 39s 953ms/step - loss: 0.3157 - accuracy: 0.8684 - val_loss: 0.4542 - val_accuracy: 0.7906
# Epoch 15/15
# 41/41 [==============================] - 34s 837ms/step - loss: 0.3233 - accuracy: 0.8668 - val_loss: 0.4431 - val_accuracy: 0.7937

# %% [markdown]
# ### Визуализация результатов обучения

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Видно, что разрыв между обучением и валидацией уменьшился до приемлемого уровня.

# %% [markdown]
# ## Оценка модели на тестовом датасете
#
# Проверим модель на данных, которые она не видела при обучении:

# %%
print("Evaluate on test data")
results = model.evaluate(test_ds)
print(f"Test loss: {results[0]}")
print(f"Test accuracy: {results[1]}")
# Out:
# Evaluate on test data
# 8/8 [==============================] - 3s 175ms/step - loss: 0.4218 - accuracy: 0.8202
# Test loss: 0.42178305983543396
# Test accuracy: 0.8201754093170166

# %% [markdown]
# ## Выводы
#
# В результате мы построили сверточную нейросеть, определяющую наличие хотдога на изображении. Accuracy-метрика модели на тестовых данных - 0.82, что достаточно высоко.
